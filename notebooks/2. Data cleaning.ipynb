# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## 1. Imports

# %% [markdown]
# ### 1.1 Libraries

# %%
# builtin
import os, time, sys, random

# data
import pandas as pd
import numpy as np
import requests
import math

# viz
import seaborn as sns
import matplotlib.pyplot as plt

# other
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1.2 Download and options

# %%
sns.set()

# %% [markdown]
# ### 1.3 Loading data

# %%
# Env Perso
df = pd.read_csv(r"C:\Users\derou\OneDrive\Bureau\DATA\PORTFOLIO\Recommandation de films\CSV\df_movies.csv")

# Env Vinci
#df = pd.read_csv(r"C:\Users\melvin.derouk\Desktop\Data formation\Movies-Recommandations\df_movies.csv")

# %% [markdown]
# ## 2. First tour

# %% [markdown]
# ### 2.1 Display

# %%
df.drop(columns= "Unnamed: 0", inplace=True)

# %%
df.head(5)
# Out:
#         ID                    Titre Date de sortie  \
# 0  1075794                      Leo     2023-11-17
# 1   872585              Oppenheimer     2023-07-19
# 2   901362             Les Trolls 3     2023-10-12
# 3   507089  Five Nights at Freddy's     2023-10-25
# 4   670292              The Creator     2023-09-27
#
#                                                Genre  Note  Popularité  \
# 0                       Animation, Comédie, Familial   7.7    1828.905
# 1                                    Drame, Histoire   8.2    1142.284
# 2  Animation, Familial, Musique, Fantastique, Com...   7.2    1121.642
# 3                                   Horreur, Mystère   7.9     779.775
# 4                  Science-Fiction, Action, Thriller   7.1     774.741
#
#                                             Synopsis  \
# 0  Leo, un lézard blasé de 74 ans, vit dans une s...
# 1  En 1942, convaincus que l'Allemagne nazie est ...
# 2  Après deux films à se tourner autour pour fina...
# 3  Mike, jeune homme perturbé, s’occupe de sa sœu...
# 4  Alors qu'une future guerre entre la race humai...
#
#                             Affiche
# 0  /pD6sL4vntUOXHmuvJPPZAgvyfd9.jpg
# 1  /boAUuJBeID7VNp4L7LNMQs8mfQS.jpg
# 2  /r5uiTUeqoERL66fNgtPVbTViHml.jpg
# 3  /tEY81I7lpiHaLJa7AZ3O4vWXmJo.jpg
# 4  /pP1cyoXFc5Br1Sg21uORSN49yyu.jpg

# %%
df.tail(5)
# Out:
#           ID          Titre Date de sortie                       Genre  Note  \
# 9995  886083     Deadstream     2022-10-20            Horreur, Comédie   6.1
# 9996   60011   Shots of War     2011-04-22             Drame, Histoire   6.7
# 9997   22307  Sœurs de sang     1973-04-18  Thriller, Horreur, Mystère   6.7
# 9998   11483        Pirates     1986-05-08           Aventure, Comédie   6.2
# 9999  586461        Swallow     2020-01-15    Drame, Thriller, Horreur   6.6
#
#       Popularité                                           Synopsis  \
# 9995      16.033  Une personnalité Internet en disgrâce tente de...
# 9996      16.033  De 1990 à 1994, quatre photographes de guerre ...
# 9997      16.033  Un soir, Danielle Breton ramène un homme chez ...
# 9998      16.033  Fin du XVIIème siècle : le terrible capitaine ...
# 9999      16.032  Hunter semble mener une vie parfaite aux côtés...
#
#                                Affiche
# 9995  /qzpeegVCMYp8lWVt4WY9S4zQ9Kp.jpg
# 9996  /aLCp9TDb8z0zP4G6c2P4s31oDIj.jpg
# 9997   /CpaW2VJX9CeUTdCv9wAjBXIIze.jpg
# 9998  /iUvJPLB1xng3zzCvc3TlpitZsl7.jpg
# 9999  /dJQeT9d2469plWFbNby5c7BbT4h.jpg

# %%
df.sample(10)
# Out:
#            ID                             Titre Date de sortie  \
# 351    126889                  Alien : Covenant     2017-05-09
# 3324  1078556  As Aventuras de Poliana: O Filme     2023-11-30
# 2855    10214                   Le Fils du Mask     2005-02-18
# 770    270303                        It Follows     2015-02-04
# 5748    14635                  Rêve de champion     2002-03-25
# 2672    97367        The Place Beyond the Pines     2013-03-14
# 2782   675319                          Zone 414     2021-09-03
# 1795   110415  Snowpiercer : Le Transperceneige     2013-08-01
# 2733    10212                            Vorace     1999-01-01
# 5783    14638                        Les Tueurs     1946-08-30
#
#                                          Genre  Note  Popularité  \
# 351          Science-Fiction, Horreur, Mystère   6.1      86.715
# 3324                         Comédie, Aventure   0.0      27.872
# 2855  Fantastique, Comédie, Familial, Aventure   4.1      30.177
# 770                           Horreur, Mystère   6.6      59.247
# 5748                           Drame, Familial   6.8      21.166
# 2672                              Drame, Crime   7.0      31.274
# 2782        Science-Fiction, Thriller, Mystère   5.4      30.570
# 1795            Action, Science-Fiction, Drame   6.9      38.550
# 2733       Aventure, Horreur, Western, Comédie   6.8      30.839
# 5783                  Crime, Mystère, Thriller   7.4      21.102
#
#                                                Synopsis  \
# 351   Les membres d’équipage du vaisseau Covenant, à...
# 3324                                                NaN
# 2855  Tim Avery, un dessinateur qui n'est pas prêt à...
# 770   Une jeune femme est poursuivie par une force s...
# 5748  Jimmy Morris, un professeur de chimie qui est ...
# 2672  Cascadeur à moto, Luke est réputé pour son spe...
# 2782  Dans un futur proche, au sein de la colonie de...
# 1795  2031, Une nouvelle ère glaciaire. Les derniers...
# 2733  Au cours du violent conflit qui opposa les Éta...
# 5783  Un soir, dans une petite ville qui traverse la...
#
#                                Affiche
# 351   /gJL4noFkpXHkNBX2MgzEo6PbYUy.jpg
# 3324  /yS5NHcsEGyXt6mTTWUxJAJUBksI.jpg
# 2855  /j6bQulQFSPBi2iN8GKcagYhAMuy.jpg
# 770   /jh8bol1N8COAGSj4ksrcUNo8xxc.jpg
# 5748  /6NgFk2dACcOd5o7XwU3QkRF1aO3.jpg
# 2672  /coIfrLBnLBC88QkHk703vIoyJXl.jpg
# 2782  /bJIq2UwwrrVP033Mk3G5paUwYnp.jpg
# 1795  /dj05CZ7X5t9iJ08PQjn6F9wyYFZ.jpg
# 2733  /afwIIAGBTczwvKkx8pJKlzaAhte.jpg
# 5783  /jOfSP32sPi2Re6BsB7yBtKtp2P1.jpg

# %% [markdown]
# ### 2.2 Structure

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              10000 non-null  int64
#  1   Titre           10000 non-null  object
#  2   Date de sortie  9990 non-null   object
#  3   Genre           9962 non-null   object
#  4   Note            10000 non-null  float64
#  5   Popularité      10000 non-null  float64
#  6   Synopsis        9243 non-null   object
#  7   Affiche         9980 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 625.1+ KB

# %%
df.nunique()
# Out:
# ID                9996
# Titre             9771
# Date de sortie    6040
# Genre             2296
# Note                73
# Popularité        8000
# Synopsis          9238
# Affiche           9976
# dtype: int64

# %% [markdown]
# ### 2.3 NaN & duplicated

# %%
#NaN

df.isna().sum()
# Out:
# ID                  0
# Titre               0
# Date de sortie     10
# Genre              38
# Note                0
# Popularité          0
# Synopsis          757
# Affiche            20
# dtype: int64

# %%
df.isna().mean().sort_values()
# Out:
# ID                0.0000
# Titre             0.0000
# Note              0.0000
# Popularité        0.0000
# Date de sortie    0.0010
# Affiche           0.0020
# Genre             0.0038
# Synopsis          0.0757
# dtype: float64

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
# Duplicated rows

df.duplicated().sum()
# Out:
# 4

# %%
# doublons par colonne

for col in df.columns:
    n = df.duplicated(subset=col).sum()
    print(f"column : {col} -> duplicated : {n}")
# Out:
# column : ID -> duplicated : 4
# column : Titre -> duplicated : 229
# column : Date de sortie -> duplicated : 3959
# column : Genre -> duplicated : 7703
# column : Note -> duplicated : 9927
# column : Popularité -> duplicated : 2000
# column : Synopsis -> duplicated : 761
# column : Affiche -> duplicated : 23

# %%
# isolement des lignes avec doublons dans "Titre"

idx = df.duplicated(subset=["Titre"], keep=False)
dbl_df = df[idx]

dbl_df.sort_values("Titre")
# Out:
#            ID              Titre Date de sortie  \
# 7189   656968  A Christmas Carol     2019-12-19
# 4964    25842  A Christmas Carol     1938-12-16
# 3636    13189  A Christmas Carol     1984-10-09
# 5614   118612              After     2012-08-27
# 6932   163733              After     2013-01-30
# ...       ...                ...            ...
# 5920   429300        À la dérive     2018-05-31
# 5008    25239       Œil pour œil     1978-11-02
# 6697    14854       Œil pour œil     1983-04-15
# 4399  1206144               Тёща     2023-11-30
# 4643  1196827               Тёща     2023-11-30
#
#                                        Genre  Note  Popularité  \
# 7189                      Drame, Fantastique   6.8      18.906
# 4964            Drame, Fantastique, Familial   7.0      22.816
# 3636  Drame, Fantastique, Téléfilm, Familial   7.4      26.646
# 5614                       Mystère, Thriller   5.5      21.412
# 6932                                 Romance   5.9      19.281
# ...                                      ...   ...         ...
# 5920             Thriller, Romance, Aventure   6.9      20.845
# 5008                       Horreur, Thriller   5.9      22.710
# 6697                           Action, Crime   6.5      19.613
# 4399                                 Comédie   0.0      24.158
# 4643                                 Comédie   0.0      23.562
#
#                                                Synopsis  \
# 7189  Ebenezer Scrooge, un vieil homme grincheux et ...
# 4964  A Londres le soir de Noël, un jeune homme rend...
# 3636                                                NaN
# 5614                                                NaN
# 6932  Paris, la nuit, une femme rencontre un homme. ...
# ...                                                 ...
# 5920  Tami Oldham et Richard Sharp décident de convo...
# 5008  Jennifer, écrivaine new-yorkaise qui a loué un...
# 6697  J.J.McQuade, policier réputé, vit solitaire. I...
# 4399                                                NaN
# 4643                                                NaN
#
#                                Affiche
# 7189  /tKW48tnZKaHLBIxxgoAf9BIpyRv.jpg
# 4964  /rJoFwqMaYyS3bmWXQGJh5qa7KMW.jpg
# 3636  /kGmpIkjVRWHQ97AiEXC0pLt5VtY.jpg
# 5614  /5AKcsJYztbcX2KsyCXtKucyUUMA.jpg
# 6932  /tnlJJL6B0evxZordxhnyLnsmfi9.jpg
# ...                                ...
# 5920  /ixO5IDavRECFXcuJGJLMBNZY9SQ.jpg
# 5008  /6T22urBLRIrMLVOpIj9qixsu2Yo.jpg
# 6697  /4iJD9cwqi5xCaVfcSxIFRUlwyYi.jpg
# 4399  /cQP3OyvmZNm6gr61rJXpbM9f2JV.jpg
# 4643  /22IvJpLFtgIVkZVRqw59Xkr4EGu.jpg
#
# [433 rows x 8 columns]

# %% [markdown]
# ### 2.4 Data inspection

# %%
df.describe(include='all')
# Out:
#                   ID                    Titre Date de sortie  Genre  \
# count   1.000000e+04                    10000           9990   9962
# unique           NaN                     9771           6040   2296
# top              NaN  Les Trois Mousquetaires     2023-12-01  Drame
# freq             NaN                        4             88    583
# mean    2.955799e+05                      NaN            NaN    NaN
# std     3.481659e+05                      NaN            NaN    NaN
# min     5.000000e+00                      NaN            NaN    NaN
# 25%     1.125875e+04                      NaN            NaN    NaN
# 50%     8.683450e+04                      NaN            NaN    NaN
# 75%     5.212198e+05                      NaN            NaN    NaN
# max     1.208769e+06                      NaN            NaN    NaN
#
#                 Note    Popularité  \
# count   10000.000000  10000.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        6.391850     32.273493
# std         1.383575     41.342856
# min         0.000000     15.427000
# 25%         6.000000     18.506250
# 50%         6.600000     22.729000
# 75%         7.200000     32.357000
# max        10.000000   1828.905000
#
#                                                  Synopsis  \
# count                                                9243
# unique                                               9238
# top     Chassées d'une petite ville de l'Ouest, Alice ...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  Affiche
# count                               9980
# unique                              9976
# top     /7HQwVOFeEZexIahUnJ3LIbrCxsc.jpg
# freq                                   2
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN

# %% [markdown]
# ## 3. Cleaning

# %% [markdown]
# ### 3.1 NaN

# %%
df.dropna(inplace=True)

# %%
df = df.drop_duplicates(subset='Synopsis')

# %%
#remplacement des valeurs manquantes en NAT dans la colonne date

df['Date de sortie'] = pd.to_datetime(df['Date de sortie'], errors='coerce')

# %% [markdown]
# ### 3.2 Drop duplicated

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %% [markdown]
# ### 4.1 Genre

# %%
#certains genres dans la colonne "Genre" sont stockés sous forme de chaînes de caractères plutôt que de listes

df['Genre'] = df['Genre'].apply(lambda x: x.split(", ") if isinstance(x, str) else x)

# %%
genres_expanded = df['Genre'].explode()

genre_counts = genres_expanded.value_counts()

df_genre_counts = genre_counts.reset_index()
df_genre_counts.columns = ['Genre', 'Nombre de films']

df_genre_counts
# Out:
#               Genre  Nombre de films
# 0             Drame             3702
# 1           Comédie             2915
# 2            Action             2661
# 3          Thriller             2513
# 4          Aventure             1828
# 5           Romance             1393
# 6             Crime             1318
# 7          Familial             1281
# 8       Fantastique             1278
# 9           Horreur             1278
# 10        Animation             1231
# 11  Science-Fiction             1184
# 12          Mystère              851
# 13         Histoire              450
# 14           Guerre              335
# 15          Musique              231
# 16         Téléfilm              170
# 17          Western              155
# 18     Documentaire               90

# %%
plt.figure(figsize=(10,8))

sns.barplot(x='Genre', y='Nombre de films', data=df_genre_counts)

plt.title('Boxplot des Scores par Genre')
plt.xlabel('Genre')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# ### 4.2 Date de sortie

# %%
df['Date de sortie'] = pd.to_datetime(df['Date de sortie'])

plt.figure(figsize=(10,6))
df['Date de sortie'].dt.year.hist(bins=30, edgecolor='black')
plt.title('Distribution des dates de sortie des films')
plt.xlabel('Année de sortie')
plt.ylabel('Nombre de films')
plt.show()

# %%
# retrait des films qui ne sont pas encore sortis (> 01/11/2023)
cutoff_date = pd.Timestamp('2023-12-01')
df = df[df["Date de sortie"] < cutoff_date]

df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 4.3 Note

# %%
df.Note.value_counts(normalize=True)
# Out:
# 6.8    0.049445
# 6.7    0.049118
# 6.5    0.048247
# 7.0    0.046722
# 6.6    0.045742
#          ...
# 2.1    0.000109
# 8.8    0.000109
# 9.5    0.000109
# 9.0    0.000109
# 2.4    0.000109
# Name: Note, Length: 63, dtype: float64

# %%
plt.figure(figsize=(8,6))

df['Note'].hist(bins=35)

plt.title("Répartition des notes", size=16)
plt.show()

# %%
df[df['Note']==0]
# Out:
#            ID                        Titre Date de sortie  \
# 802    365620                      Ferrari     2023-11-30
# 1445   872976  デジモンアドベンチャー02 THE BEGINNING     2023-10-27
# 2637   628922                  Black Flies     2023-11-30
# 3781   951219                  Ardente·x·s     2023-11-30
# 5264  1173807              Her Şeye Rağmen     2023-09-29
# 5582   724846                       Conann     2023-11-29
# 6672  1016324          Si proche du soleil     2023-11-29
#
#                                    Genre  Note  Popularité  \
# 802                    [Drame, Histoire]   0.0      55.033
# 1445  [Aventure, Animation, Fantastique]   0.0      41.089
# 2637                   [Drame, Thriller]   0.0      30.006
# 3781                      [Documentaire]   0.0      24.832
# 5264                             [Drame]   0.0      21.024
# 5582                       [Fantastique]   0.0      20.430
# 6672                             [Drame]   0.0      18.748
#
#                                                Synopsis  \
# 802   Au cours de l'été 1957, Enzo Ferrari, ancien p...
# 1445  En 2012, après les événements de Digimon Adven...
# 2637  Ollie Cross, jeune ambulancier New-Yorkais, fa...
# 3781  À Lausanne, en Suisse, un groupe de jeunes fem...
# 5264  Ilhan Dogan ! Un homme ambitieux et courageux ...
# 5582  Parcourant les abîmes, le chien des enfers Rai...
# 6672  Chaque fois qu’il se réveille, un jeune homme ...
#
#                                Affiche
# 802   /aCHxie2RrP2RjYJAmsnVTP2bf2X.jpg
# 1445  /jaCatH56H6q6Xs0tK12amOIJRCA.jpg
# 2637  /5JQi3bIQdRyMKImzzqNb82b0Hbh.jpg
# 3781  /wDgzTIJ5iJysi43Wppc9xZgKdew.jpg
# 5264  /xrpgepIdD1yrZQlLR1Ty7XnEQIk.jpg
# 5582  /quZxF9nCFmBeMi5eFekVWRoRfw8.jpg
# 6672  /bkKic8THHLIc6ixRaGcG4WFwsET.jpg

# %% [markdown]
# ### 4.4 Synopsis

# %%
df.Synopsis.apply(lambda i : len(i))
# Out:
# 0       528
# 1       629
# 2       530
# 3       643
# 4       223
#        ...
# 9177    264
# 9178    562
# 9179    345
# 9180    295
# 9181    549
# Name: Synopsis, Length: 9182, dtype: int64

# %%
tmp = df.Synopsis.str.len()

plt.figure(figsize=(10,4))
sns.boxplot(tmp)
# Out:
# <AxesSubplot:xlabel='Synopsis'>

# %%
sns.displot(tmp)

# %%
df['len_txt'] = tmp
df.head(5)
# Out:
#         ID                    Titre Date de sortie  \
# 0  1075794                      Leo     2023-11-17
# 1   872585              Oppenheimer     2023-07-19
# 2   901362             Les Trolls 3     2023-10-12
# 3   507089  Five Nights at Freddy's     2023-10-25
# 4   670292              The Creator     2023-09-27
#
#                                                Genre  Note  Popularité  \
# 0                     [Animation, Comédie, Familial]   7.7    1828.905
# 1                                  [Drame, Histoire]   8.2    1142.284
# 2  [Animation, Familial, Musique, Fantastique, Co...   7.2    1121.642
# 3                                 [Horreur, Mystère]   7.9     779.775
# 4                [Science-Fiction, Action, Thriller]   7.1     774.741
#
#                                             Synopsis  \
# 0  Leo, un lézard blasé de 74 ans, vit dans une s...
# 1  En 1942, convaincus que l'Allemagne nazie est ...
# 2  Après deux films à se tourner autour pour fina...
# 3  Mike, jeune homme perturbé, s’occupe de sa sœu...
# 4  Alors qu'une future guerre entre la race humai...
#
#                             Affiche  len_txt
# 0  /pD6sL4vntUOXHmuvJPPZAgvyfd9.jpg      528
# 1  /boAUuJBeID7VNp4L7LNMQs8mfQS.jpg      629
# 2  /r5uiTUeqoERL66fNgtPVbTViHml.jpg      530
# 3  /tEY81I7lpiHaLJa7AZ3O4vWXmJo.jpg      643
# 4  /pP1cyoXFc5Br1Sg21uORSN49yyu.jpg      223

# %%
df.sort_values("len_txt").head(5)
# Out:
#           ID              Titre Date de sortie  \
# 4082   44363             Frozen     2010-02-05
# 5316  876716       Ciao Alberto     2021-11-12
# 5544  336445        Army of One     2016-11-04
# 4364   52212            Miranda     1985-10-15
# 8883    8286  La Femme infidèle     1969-01-22
#
#                                             Genre  Note  Popularité  \
# 4082                                   [Thriller]   6.0      23.941
# 5316  [Animation, Comédie, Familial, Fantastique]   7.5      20.932
# 5544                                    [Comédie]   5.2      20.484
# 4364                           [Comédie, Romance]   5.2      23.132
# 8883                     [Crime, Drame, Thriller]   7.0      16.282
#
#                                                Synopsis  \
# 4082     Trois skieurs sont bloqués sur un télésiège...
# 5316   Spin-off de Luca, des studios d’animation Pixar.
# 5544  Un homme décide de traquer seul Oussama Ben La...
# 4364  Miranda cherche un mari et essaye plusieurs ho...
# 8883  Un homme est amené à croire que sa femme le tr...
#
#                                Affiche  len_txt
# 4082  /9RUF2GfgvD4m4RoNxEXZchQ14p9.jpg       46
# 5316  /jrfgfSc5d7wNlez1TSz8U0fggnZ.jpg       48
# 5544  /9XKBJovNQyNRQo382uQ7woFVJ5G.jpg       50
# 4364  /iaN8NhkU0qBhcT18KFlUa33Gsz9.jpg       51
# 8883  /7aiBnKUjfvKwkHO3KQgXR2nycAj.jpg       51

# %%
df.sort_values("len_txt").tail(5)
# Out:
#           ID                               Titre Date de sortie  \
# 3504  213681                        Les Cerveaux     2016-09-29
# 4094    6878                 L'Incroyable Voyage     1993-02-03
# 3851    9550     Le Secret des poignards volants     2004-05-19
# 1927  437068                       A Taxi Driver     2017-08-02
# 2746  618344  Justice League Dark: Apokolips War     2020-05-05
#
#                                      Genre  Note  Popularité  \
# 3504              [Action, Comédie, Crime]   5.7      25.853
# 4094         [Aventure, Comédie, Familial]   6.9      23.914
# 3851             [Aventure, Drame, Action]   7.3      24.623
# 1927             [Action, Drame, Histoire]   8.1      35.247
# 2746  [Animation, Action, Science-Fiction]   8.3      29.267
#
#                                                Synopsis  \
# 3504  La vie de David Ghantt n’a rien de compliqué. ...
# 4094  Le film raconte les aventures de Shadow, un go...
# 3851  En cette année 859, la Chine est ravagée par l...
# 1927  Mai 1980, Séoul. Des manifestations dénonçant ...
# 2746  Suite à ses deux invasions ratées de la Terre,...
#
#                                Affiche  len_txt
# 3504  /iMVeDnL6toG3WWdthXAwqVjZl8e.jpg      995
# 4094  /kbm5Met5uzwuccVkNFlEahSKK3P.jpg      998
# 3851  /cgL3HcV7wYVkTZ5xkPbSMqgqVkL.jpg      998
# 1927  /5n7sbyS3QTIIZ1epq7QiNxUwWpK.jpg      998
# 2746  /c01Y4suApJ1Wic2xLmaq1QYcfoZ.jpg      999

# %% [markdown]
# ### 4.5 Multivariate analysis

# %%
corr = df.corr()
corr
# Out:
#                   ID      Note  Popularité   len_txt
# ID          1.000000 -0.005518    0.159523 -0.244505
# Note       -0.005518  1.000000    0.121854  0.068754
# Popularité  0.159523  0.121854    1.000000  0.031373
# len_txt    -0.244505  0.068754    0.031373  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=["len_txt"], inplace=True)

# %%
df.to_csv(r"C:\Users\derou\OneDrive\Bureau\DATA\PORTFOLIO\Recommandation de films\CSV\df_movies_cleaned.csv", index=False)
